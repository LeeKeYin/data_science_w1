# %%
# %pip install kagglehub
# %pip install "kagglehub[pandas-datasets]"
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip3.12 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip3.12 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

path = kagglehub.dataset_download("kingabzpro/cosmetics-datasets")

path

# %%
import pandas as pd

# 1. Find some real dataset. Load it on Colab, Kaggle etc. Try to visualize some of it 
file_path = "./datasets/cosmetics.csv"

# Load the latest version
df = pd.read_csv(file_path)
df.head()
# Out:
#          Label           Brand                                           Name  \
# 0  Moisturizer          LA MER                                Crème de la Mer
# 1  Moisturizer           SK-II                       Facial Treatment Essence
# 2  Moisturizer  DRUNK ELEPHANT                     Protini™ Polypeptide Cream
# 3  Moisturizer          LA MER                    The Moisturizing Soft Cream
# 4  Moisturizer    IT COSMETICS  Your Skin But Better™ CC+™ Cream with SPF 50+
#
#    Price  Rank                                        Ingredients  \
# 0    175   4.1  Algae (Seaweed) Extract, Mineral Oil, Petrolat...
# 1    179   4.1  Galactomyces Ferment Filtrate (Pitera), Butyle...
# 2     68   4.4  Water, Dicaprylyl Carbonate, Glycerin, Ceteary...
# 3    175   3.8  Algae (Seaweed) Extract, Cyclopentasiloxane, P...
# 4     38   4.1  Water, Snail Secretion Filtrate, Phenyl Trimet...
#
#    Combination  Dry  Normal  Oily  Sensitive
# 0            1    1       1     1          1
# ...

# %%
# 2. Evaluate if the data is good or not. Does it have enough samples?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Label        506 non-null    object
#  1   Brand        506 non-null    object
#  2   Name         506 non-null    object
#  3   Price        506 non-null    int64
#  4   Rank         506 non-null    float64
#  5   Ingredients  506 non-null    object
#  6   Combination  506 non-null    int64
#  7   Dry          506 non-null    int64
#  8   Normal       506 non-null    int64
#  9   Oily         506 non-null    int64
#  10  Sensitive    506 non-null    int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 43.6+ KB

# %%
# It contains 506 entries, which is a decent size for basic analysis.

# %%
# 3. How many features does it have? Is it enough?
df.columns
# Out:
# Index(['Label', 'Brand', 'Name', 'Price', 'Rank', 'Ingredients', 'Combination',
#        'Dry', 'Normal', 'Oily', 'Sensitive'],
#       dtype='object')

# %%
# It has 11 features, which should be sufficient for a variety of analyses depending on the context of the dataset.

# %%
# 4. How many samples/observation does it have? Is it enough?
df.shape
# Out:
# (506, 11)

# %%
# Yes

# %%
# 5. What are the datatypes does the dataset consist of?
df.dtypes
# Out:
# Label           object
# Brand           object
# Name            object
# Price            int64
# Rank           float64
# Ingredients     object
# Combination      int64
# Dry              int64
# Normal           int64
# Oily             int64
# Sensitive        int64
# dtype: object

# %%
# object, int64, float64

# %%
# 6. How many columns have null values? If yes, which column, which rows
df.isnull().sum()
# Out:
# Label          0
# Brand          0
# Name           0
# Price          0
# Rank           0
# Ingredients    0
# Combination    0
# Dry            0
# Normal         0
# Oily           0
# Sensitive      0
# dtype: int64

# %%
# it has no null values

# %%
# 7. Which column is the feature, which is the target output?

# Feature columns could include 'Brand', 'Category', 'Price', 'Rating', 'Reviews', 'Ingredients', 'Skin Type', 'Product Type', and 'Volume'. 
# The target output could be 'Best Seller' if the goal is to predict whether a product is a best seller based on its features.

# %%
# 8. Does it have missing values? If yes, which column, which row. 

# Same as question 6

# %%
# 9. What kind of question can be asked, should we ask. Does the dataset suits the question we are asking?

# What are the top-rated cosmetic products?
